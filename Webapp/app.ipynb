# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/

# %%
# !ls
# Out:
# app.ipynb	       originalmodel.pkl  __pycache__  templates  Username
# feature_extraction.py  Password		  static       uploads

# %%
# !pip install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.3.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Downloading pyngrok-7.3.0-py3-none-any.whl (25 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.3.0

# %%
# !pip install pefile
# Out:
# Collecting pefile
#   Downloading pefile-2024.8.26-py3-none-any.whl.metadata (1.4 kB)
# Downloading pefile-2024.8.26-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: pefile
# Successfully installed pefile-2024.8.26

# %%
#import libraries
from pyngrok import ngrok
# Import the python file containing the ML model
from flask import Flask, request, render_template,jsonify # Import flask libraries
import pandas as pd # Pandas library for dealing with tabular datasest
import numpy as np  # Numpy library for Numerical operations
import json # to deal with JSON data format
import os
from werkzeug.utils import secure_filename
import shap
import joblib
import os
from feature_extraction import extract_features

# %%
port_no = 5000

# %%
#Initialize the flask App

# Initialize the flask class and specify the templates directory
app = Flask(__name__, template_folder='templates')




# The NGROK auth key
ngrok.set_auth_token("2tP4OCkOovSa9SZZmVgL8SGVauS_3B84UtJ55Tt5DUuQnaso5")
public_url =  ngrok.connect(port_no).public_url




model = joblib.load('forest.pkl')


UPLOAD_FOLDER = 'uploads'
if not os.path.exists(UPLOAD_FOLDER):
    os.makedirs(UPLOAD_FOLDER)

app.config['UPLOAD_FOLDER'] = UPLOAD_FOLDER
ALLOWED_EXTENSIONS = {'dll', 'exe'}

def allowed_file(filename):
    return '.' in filename and filename.rsplit('.', 1)[1].lower() in ALLOWED_EXTENSIONS



#default page of our web-app
@app.route('/')
def landing():
    return render_template('landing.html')





@app.route('/signup',methods=['POST'])
def signup():
    if request.method == 'POST':
        return render_template('signup.html')

@app.route('/signupsuccess',methods=['POST'])
def signupsuccess():
    if request.method == 'POST':
        credentials = [(x) for x in request.form.values()]
        print(credentials)
        username = credentials[0]
        password = credentials[1]
        print(type(username))

        file = open("Username/username.txt", "w")
        a = file.write(username)
        file.close()

        file = open("Password/password.txt", "w")
        a = file.write(password)
        file.close()
        return render_template('signupsuccess.html')




@app.route('/login',methods=['POST'])
def login():
    if request.method == 'POST':
        return render_template('login.html')



@app.route('/home',methods=['POST'])
def home():
    if request.method == 'POST':
        lcredentials = [(x) for x in request.form.values()]
        print(lcredentials)
        lusername = lcredentials[0]
        lpassword = lcredentials[1]
        print(type(lusername))

        f = open("Username/username.txt", "r")
        username = f.read()
        f = open("Password/password.txt", "r")
        password = f.read()
        print(lusername, username, lpassword, password)

        if username==lusername and password==lpassword:
            print('match')
            template = 'home.html'
        elif username!=lusername or password!=lpassword:
            print('No')
            template = 'loginfail.html'

        return render_template(template)



@app.route('/predict', methods=['POST'])
def predict():
    # Check if a file is uploaded
    if 'file' in request.files:
        file = request.files['file']

        if file.filename == '' or not allowed_file(file.filename):
            return render_template('home.html', error="Unsupported file type.")

        # Construct the full file path
        file_path = os.path.join(app.config['UPLOAD_FOLDER'], file.filename)

        # Save the file
        file.save(file_path)

        # Use the model for prediction if the file is `.exe` or `.dll`
        if allowed_file(file.filename):
            features = extract_features(file_path)  # Your feature extraction function
            prediction = model.predict(features)     # Predict using your model
            result = {
                "type": "file",
                "prediction": "Malware" if prediction[0] == 1 else "Safe",
                "file_name": file.filename
            }

        return render_template('output.html', result=result)

    return render_template('home.html', error="No file uploaded.")






    return render_template('output.html', prediction_text='{}'.format(out))


print(f"To acces the Gloable link please click {public_url}")
app.run(port=port_no)
# Out:
# To acces the Gloable link please click https://79422ca296a2.ngrok-free.app
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:06] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:07] "GET /static/css/style2.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:07] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:07] "GET /static/bg.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:09] "GET /static/favicon.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:09] "POST /login HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:10] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:10] "GET /main.js HTTP/1.1" 404 -
# ['a', 'a']
# <class 'str'>
# a aa a aa
# No
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:14] "POST /home HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:15] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:15] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:17] "POST /login HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:18] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:18] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:21] "POST /home HTTP/1.1" 200 -
# ['aa', 'aa']
# <class 'str'>
# aa aa aa aa
# match
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:22] "GET /static/css/style.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:22] "GET /static/banner.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:22] "GET /static/ds.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:23] "GET /static/bg2.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:23] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:30] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:31] "GET /static/ds.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:31] "GET /static/banner.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:31] "GET /static/css/style.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:32] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:32] "GET /static/bg2.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:40] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:40] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:40] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:41] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:59] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:59] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:03:59] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:09] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:10] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:10] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:20] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:20] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:20] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:27] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:28] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:28] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:53] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:53] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:53] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:04:54] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:03] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:04] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:04] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:35] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:36] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:36] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:37] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:44] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:45] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:45] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:55] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:55] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:05:55] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:06:14] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:06:14] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:06:14] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:06:15] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:06:22] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:06:23] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:06:23] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:06:40] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:06:41] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:06:41] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:13] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:14] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:14] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:14] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:22] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:23] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:23] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:39] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:40] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:40] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:47] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:47] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:47] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:48] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:54] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:55] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:07:55] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:03] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:04] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:04] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:27] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:28] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:28] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:29] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:35] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:35] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:35] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:55] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:56] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:08:56] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:03] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:04] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:04] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:22] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:23] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:23] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:24] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:31] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:32] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:32] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:45] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:46] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:46] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:57] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:57] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:57] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:09:59] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:10:05] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:10:06] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:10:06] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:10:07] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:10:44] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:10:44] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:10:44] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:10:45] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:11:09] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:11:10] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:11:10] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:11:19] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:11:20] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:11:20] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:11:21] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:05] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:06] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:06] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:07] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:31] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:32] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:32] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:33] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:41] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:41] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:41] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:42] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:50] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:50] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:50] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:12:51] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:12] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:13] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:13] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:13] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:20] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:20] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:20] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:21] "GET /static/bg.jpg HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:26] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:27] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:27] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:36] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:36] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:36] "GET /main.js HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:43] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:44] "GET /static/css/style2.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [19/Aug/2025 11:13:44] "GET /main.js HTTP/1.1" 404 -
